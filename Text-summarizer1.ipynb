MB 3.5 MB/s eta 0:00:01
#      ----------------------------------       12.9/15.0 MB 3.8 MB/s eta 0:00:01
#      ----------------------------------       13.1/15.0 MB 3.8 MB/s eta 0:00:01
#      -----------------------------------      13.3/15.0 MB 3.8 MB/s eta 0:00:01
#      ------------------------------------     13.5/15.0 MB 3.9 MB/s eta 0:00:01
#      ------------------------------------     13.7/15.0 MB 3.9 MB/s eta 0:00:01
#      ------------------------------------     13.7/15.0 MB 3.8 MB/s eta 0:00:01
#      ------------------------------------     13.7/15.0 MB 3.8 MB/s eta 0:00:01
#      ------------------------------------     13.7/15.0 MB 3.8 MB/s eta 0:00:01
#      ------------------------------------     13.7/15.0 MB 3.8 MB/s eta 0:00:01
#      ------------------------------------     13.8/15.0 MB 3.6 MB/s eta 0:00:01
#      -------------------------------------    14.1/15.0 MB 3.6 MB/s eta 0:00:01
#      --------------------------------------   14.3/15.0 MB 3.6 MB/s eta 0:00:01
#      --------------------------------------   14.5/15.0 MB 3.6 MB/s eta 0:00:01
#      ---------------------------------------  14.7/15.0 MB 3.6 MB/s eta 0:00:01
#      ---------------------------------------  15.0/15.0 MB 3.6 MB/s eta 0:00:01
#      ---------------------------------------  15.0/15.0 MB 3.7 MB/s eta 0:00:01
#      ---------------------------------------- 15.0/15.0 MB 3.5 MB/s eta 0:00:00
# Collecting oauth2client>=4.0.0 (from pydrive)
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#                                               0.0/98.2 kB ? eta -:--:--
#      ---------------------------------------- 98.2/98.2 kB 5.5 MB/s eta 0:00:00
# Collecting PyYAML>=3.0 (from pydrive)
#   Downloading pyyaml-6.0.3-cp311-cp311-win_amd64.whl (158 kB)
#                                               0.0/158.8 kB ? eta -:--:--
#      -------------------------------------- 158.8/158.8 kB 4.8 MB/s eta 0:00:00
# Collecting httplib2<1.0.0,>=0.19.0 (from google-api-python-client>=1.2->pydrive)
#   Downloading httplib2-0.31.2-py3-none-any.whl (91 kB)
#                                               0.0/91.1 kB ? eta -:--:--
#      ---------------------------------------- 91.1/91.1 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client>=1.2->pydrive) (2.49.2)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client>=1.2->pydrive)
#   Downloading google_auth_httplib2-0.3.1-py3-none-any.whl (9.5 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 (from google-api-python-client>=1.2->pydrive)
#   Downloading google_api_core-2.30.3-py3-none-any.whl (173 kB)
#                                               0.0/173.3 kB ? eta -:--:--
#      -------------------------------------- 173.3/173.3 kB 3.5 MB/s eta 0:00:00
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client>=1.2->pydrive)
#   Downloading uritemplate-4.2.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from oauth2client>=4.0.0->pydrive) (0.6.3)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from oauth2client>=4.0.0->pydrive) (0.4.2)
# Collecting rsa>=3.1.4 (from oauth2client>=4.0.0->pydrive)
#   Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: six>=1.6.1 in c:\users\dell\appdata\roaming\python\python311\site-packages (from oauth2client>=4.0.0->pydrive) (1.17.0)
# Collecting googleapis-common-protos<2.0.0,>=1.63.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.2->pydrive)
#   Downloading googleapis_common_protos-1.74.0-py3-none-any.whl (300 kB)
#                                               0.0/300.7 kB ? eta -:--:--
#      ---------------------------------      266.2/300.7 kB 5.4 MB/s eta 0:00:01
#      -------------------------------------- 300.7/300.7 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.2->pydrive) (4.25.9)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.2->pydrive)
#   Downloading proto_plus-1.27.2-py3-none-any.whl (50 kB)
#                                               0.0/50.5 kB ? eta -:--:--
#      ---------------------------------------- 50.5/50.5 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.2->pydrive) (2.33.1)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client>=1.2->pydrive) (46.0.7)
# Requirement already satisfied: pyparsing<4,>=3.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client>=1.2->pydrive) (3.3.2)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client>=1.2->pydrive) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.2->pydrive) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.2->pydrive) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.2->pydrive) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.2->pydrive) (2026.2.25)
# Requirement already satisfied: pycparser in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client>=1.2->pydrive) (3.0)
# Building wheels for collected packages: pydrive
#   Building wheel for pydrive (setup.py): started
#   Building wheel for pydrive (setup.py): finished with status 'done'
#   Created wheel for pydrive: filename=PyDrive-1.3.1-py3-none-any.whl size=27464 sha256=ef70fec67d621a60e5487825219baddb878073114c6fe84d4997695ce54f833b
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\31\d5\09\88865e0059104686eb8365ca1d36a8b27deef34232c3b62c90
# Successfully built pydrive
# Installing collected packages: uritemplate, rsa, PyYAML, proto-plus, httplib2, googleapis-common-protos, oauth2client, google-auth-httplib2, google-api-core, google-api-python-client, pydrive
# Successfully installed PyYAML-6.0.3 google-api-core-2.30.3 google-api-python-client-2.194.0 google-auth-httplib2-0.3.1 googleapis-common-protos-1.74.0 httplib2-0.31.2 oauth2client-4.1.3 proto-plus-1.27.2 pydrive-1.3.1 rsa-4.9.1 uritemplate-4.2.0

# %%
# !pip install -U nltk # To Upgrade NLTK to >3.5 for METEOR score
# Out:
# ERROR: Invalid requirement: '#'
#
# [notice] A new release of pip is available: 23.1.2 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk

print('The nltk version is {}.'.format(nltk.__version__)) # Verify version >3.5
# Out:
# The nltk version is 3.9.4.

# %%
import numpy as np 
import pandas as pd

# %%
import os
print(os.listdir(r'C:\Users\Dell\Downloads'))
# Out:
# ['Anaconda3-2025.12-2-Windows-x86_64.exe', 'angular_lazy_loading_lab.docx', 'breast_cancer.csv', 'desktop.ini', 'Experiment No.1 (1).docx', 'Experiment No.1 (2).docx', 'Experiment No.1.docx', 'image.png', 'IMDB Dataset.txt', 'links.csv', 'MAD EX (1) (1).doc', 'MAD EX (1).doc', 'MAD EX.doc', 'mongodb-windows-x86_64-8.2.6-signed.msi', 'mosquitto-2.1.2-install-windows-x64.exe', 'movies.csv', 'movie_genres.csv', 'news_summary.csv', 'node_experiment5.docx', 'openssl-4.0.0', 'openssl-4.0.0.tar.gz', 'Polity lecture 2.pdf', 'Polity The making of the constitution.pdf', 'Postman Agent v0.4.87 (x64).exe', 'Project (1).docx', 'Project.docx', 'Python-3.11.11.tar.xz', 'python-3.11.4-amd64.exe', 'ratings.csv', 'RxJS_Angular_Lab.docx', 'SubmittedData.pdf', 'tags.csv', 'Time and Work (Railway-2026) Practice Set.pdf', 'Time and Work 5classnotes.pdf', 'Time and Work class - 2 classnotes (1).pdf.crdownload', 'Time and Work class - 2 classnotes.pdf', 'Time and Work class -1 classnotes (1).pdf.crdownload', 'Time and Work class -1 classnotes.pdf', 'truck_sample.png', 'user_reviews.csv']

# %%
import pandas as pd

summary = pd.read_csv(
    "https://raw.githubusercontent.com/sunnysai12345/News_Summary/master/news_summary.csv",
    encoding='latin-1'
)

raw = pd.read_csv(
    "https://raw.githubusercontent.com/sunnysai12345/News_Summary/master/news_summary_more.csv",
    encoding='latin-1'
)

print(summary.head())
# Out:
#                author                  date  \
# 0        Chhavi Tyagi  03 Aug 2017,Thursday
# 1         Daisy Mowke  03 Aug 2017,Thursday
# 2      Arshiya Chopra  03 Aug 2017,Thursday
# 3       Sumedha Sehra  03 Aug 2017,Thursday
# 4  Aarushi Maheshwari  03 Aug 2017,Thursday
#
#                                            headlines  \
# 0  Daman & Diu revokes mandatory Rakshabandhan in...
# 1  Malaika slams user who trolled her for 'divorc...
# 2  'Virgin' now corrected to 'Unmarried' in IGIMS...
# 3  Aaj aapne pakad liya: LeT man Dujana before be...
# 4  Hotel staff to get training to spot signs of s...
#
#                                            read_more  \
# 0  http://www.hindustantimes.com/india-news/raksh...
# 1  http://www.hindustantimes.com/bollywood/malaik...
# 2  http://www.hindustantimes.com/patna/bihar-igim...
# 3  http://indiatoday.intoday.in/story/abu-dujana-...
# 4  http://indiatoday.intoday.in/story/sex-traffic...
#
#                                                 text  \
# 0  The Administration of Union Territory Daman an...
# 1  Malaika Arora slammed an Instagram user who tr...
# 2  The Indira Gandhi Institute of Medical Science...
# 3  Lashkar-e-Taiba's Kashmir commander Abu Dujana...
# 4  Hotels in Maharashtra will train their staff t...
#
#                                                ctext
# 0  The Daman and Diu administration on Wednesday ...
# 1  From her special numbers to TV?appearances, Bo...
# 2  The Indira Gandhi Institute of Medical Science...
# 3  Lashkar-e-Taiba's Kashmir commander Abu Dujana...
# 4  Hotels in Mumbai and other Indian cities are t...

# %%
pre_data1 =  raw.iloc[:,0:2].copy()

pre_data2 = summary.iloc[:,0:6].copy()
pre_data2['text'] = pre_data2['author'].str.cat(pre_data2['date'].str.cat(pre_data2['read_more'].str.cat(pre_data2['text'].str.cat(pre_data2['ctext'], sep = " "), sep =" "),sep= " "), sep = " ")

# %%
pre_data = pd.DataFrame()
pre_data['text'] = pd.concat([pre_data1['text'], pre_data2['text']], ignore_index=True)
pre_data['summary'] = pd.concat([pre_data1['headlines'],pre_data2['headlines']],ignore_index = True)

# %%
pre_data.head(2)
# Out:
#                                                 text  \
# 0  Saurav Kant, an alumnus of upGrad and IIIT-B's...
# 1  Kunal Shah's credit card bill payment platform...
#
#                                              summary
# 0  upGrad learner switches to career in ML & Al w...
# 1  Delhi techie wins free food from Swiggy for on...

# %%
pre_data['text'][:10]
# Out:
# 0    Saurav Kant, an alumnus of upGrad and IIIT-B's...
# 1    Kunal Shah's credit card bill payment platform...
# 2    New Zealand defeated India by 8 wickets in the...
# 3    With Aegon Life iTerm Insurance plan, customer...
# 4    Speaking about the sexual harassment allegatio...
# 5    Pakistani singer Rahat Fateh Ali Khan has deni...
# 6    India recorded their lowest ODI total in New Z...
# 7    Weeks after ex-CBI Director Alok Verma told th...
# 8    Andhra Pradesh CM N Chandrababu Naidu has said...
# 9    Congress candidate Shafia Zubair won the Ramga...
# Name: text, dtype: str

# %%
import re

#Removes non-alphabetic characters:
def text_strip(column):
    for row in column:
        
        row=re.sub("(\\t)", ' ', str(row)).lower() #delete escape charecters
        row=re.sub("(\\r)", ' ', str(row)).lower() 
        row=re.sub("(\\n)", ' ', str(row)).lower()
        
        row=re.sub("(__+)", ' ', str(row)).lower()   #delete _ if more than one time repeatedly
        row=re.sub("(--+)", ' ', str(row)).lower()   #delete - if more than one time repeatedly
        row=re.sub("(~~+)", ' ', str(row)).lower()   #delete ~ if more than one time repeatedly
        row=re.sub("(\+\++)", ' ', str(row)).lower()   #delete + if more than one time repeatedly
        row=re.sub("(\.\.+)", ' ', str(row)).lower()   #delete . if more than one time repeatedly
        
        row=re.sub(r"[<>()|&©ø\[\]\'\",;?~*!]", ' ', str(row)).lower() #delete <>()|&©ø"',;?~*!
        
        row=re.sub("(mailto:)", ' ', str(row)).lower() #delete mailto:
        row=re.sub(r"(\\x9\d)", ' ', str(row)).lower() #delete \x9* in text
        row=re.sub("([iI][nN][cC]\d+)", 'INC_NUM', str(row)).lower() #replace INC nums to INC_NUM
        row=re.sub("([cC][mM]\d+)|([cC][hH][gG]\d+)", 'CM_NUM', str(row)).lower() #replace CM# and CHG# to CM_NUM
        
        
        row=re.sub("(\.\s+)", ' ', str(row)).lower() #delete full stop at end of words(not between)
        row=re.sub("(\-\s+)", ' ', str(row)).lower() #delete - at end of words(not between)
        row=re.sub("(\:\s+)", ' ', str(row)).lower() #delete : at end of words(not between)
        
        row=re.sub("(\s+.\s+)", ' ', str(row)).lower() #delete any single charecters hanging between 2 spaces
        
        # Change url http://www.youtube.com/watch/43865346kcre8375 ====> www.youtube.com
        try:
            url = re.search(r'((https*:\/*)([^\/\s]+))(.[^\s]+)', str(row))
            repl_url = url.group(3)
            row = re.sub(r'((https*:\/*)([^\/\s]+))(.[^\s]+)',repl_url, str(row))
        except:
            pass #there might be emails with no url in them
        

        
        row = re.sub("(\s+)",' ',str(row)).lower() #delete multiple spaces
        
        #Should always be last
        row=re.sub("(\s+.\s+)", ' ', str(row)).lower() #delete any single charecters hanging between 2 spaces

        
        
        yield row

# %%
pre_data = pd.read_csv('C:/Users/Dell/Downloads/news_summary.csv', encoding='latin-1')

# %%
print(pre_data.columns)
# Out:
# Index(['author', 'date', 'headlines', 'read_more', 'text', 'ctext'], dtype='str')

# %%
import pandas as pd

pre_data = pd.read_csv(
    'C:/Users/Dell/Downloads/news_summary.csv',
    encoding='latin-1'
)

# %%
print(pre_data.head())
# Out:
#                author                  date  \
# 0        Chhavi Tyagi  03 Aug 2017,Thursday
# 1         Daisy Mowke  03 Aug 2017,Thursday
# 2      Arshiya Chopra  03 Aug 2017,Thursday
# 3       Sumedha Sehra  03 Aug 2017,Thursday
# 4  Aarushi Maheshwari  03 Aug 2017,Thursday
#
#                                            headlines  \
# 0  Daman & Diu revokes mandatory Rakshabandhan in...
# 1  Malaika slams user who trolled her for 'divorc...
# 2  'Virgin' now corrected to 'Unmarried' in IGIMS...
# 3  Aaj aapne pakad liya: LeT man Dujana before be...
# 4  Hotel staff to get training to spot signs of s...
#
#                                            read_more  \
# 0  http://www.hindustantimes.com/india-news/raksh...
# 1  http://www.hindustantimes.com/bollywood/malaik...
# 2  http://www.hindustantimes.com/patna/bihar-igim...
# 3  http://indiatoday.intoday.in/story/abu-dujana-...
# 4  http://indiatoday.intoday.in/story/sex-traffic...
#
#                                                 text  \
# 0  The Administration of Union Territory Daman an...
# 1  Malaika Arora slammed an Instagram user who tr...
# 2  The Indira Gandhi Institute of Medical Science...
# 3  Lashkar-e-Taiba's Kashmir commander Abu Dujana...
# 4  Hotels in Maharashtra will train their staff t...
#
#                                                ctext
# 0  The Daman and Diu administration on Wednesday ...
# 1  From her special numbers to TV?appearances, Bo...
# 2  The Indira Gandhi Institute of Medical Science...
# 3  Lashkar-e-Taiba's Kashmir commander Abu Dujana...
# 4  Hotels in Mumbai and other Indian cities are t...

# %%
import re

def text_strip(text):
    text = str(text).lower()
    text = re.sub(r'[^\w\s]', '', text)  # remove punctuation
    text = re.sub(r'\s+', ' ', text)     # remove extra spaces
    return text.strip()

# %%
cleaning1 = pre_data['text'].apply(text_strip)
cleaning2 = pre_data['headlines'].apply(text_strip)

# %%
import sys
# !{sys.executable} -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#                                               0.0/12.8 MB ? eta -:--:--
#                                               0.0/12.8 MB ? eta -:--:--
#                                              0.0/12.8 MB 495.5 kB/s eta 0:00:26
#                                              0.1/12.8 MB 469.7 kB/s eta 0:00:28
#                                              0.1/12.8 MB 525.1 kB/s eta 0:00:25
#                                              0.1/12.8 MB 602.4 kB/s eta 0:00:22
#                                              0.2/12.8 MB 656.4 kB/s eta 0:00:20
#                                              0.2/12.8 MB 655.1 kB/s eta 0:00:20
#                                              0.2/12.8 MB 625.1 kB/s eta 0:00:21
#                                              0.3/12.8 MB 628.5 kB/s eta 0:00:20
#                                              0.3/12.8 MB 628.5 kB/s eta 0:00:20
#                                              0.3/12.8 MB 593.9 kB/s eta 0:00:22
#      -                                       0.4/12.8 MB 655.7 kB/s eta 0:00:19
#      -                                       0.4/12.8 MB 603.4 kB/s eta 0:00:21
#      -                                       0.4/12.8 MB 603.4 kB/s eta 0:00:21
#      -                                       0.4/12.8 MB 594.3 kB/s eta 0:00:21
#      -                                       0.5/12.8 MB 640.9 kB/s eta 0:00:20
#      -                                       0.6/12.8 MB 694.9 kB/s eta 0:00:18
#      -                                       0.6/12.8 MB 694.9 kB/s eta 0:00:18
#      -                                       0.6/12.8 MB 690.5 kB/s eta 0:00:18
#      -                                       0.6/12.8 MB 690.5 kB/s eta 0:00:18
#      --                                      0.7/12.8 MB 686.9 kB/s eta 0:00:18
#      --                                      0.7/12.8 MB 716.8 kB/s eta 0:00:17
#      --                                      0.7/12.8 MB 716.8 kB/s eta 0:00:17
#      --                                      0.8/12.8 MB 701.7 kB/s eta 0:00:18
#      --                                      0.9/12.8 MB 770.7 kB/s eta 0:00:16
#      --                                      1.0/12.8 MB 791.6 kB/s eta 0:00:15
#      ------------------------------------   12.1/12.8 MB 800.4 kB/s eta 0:00:01
#      ------------------------------------   12.1/12.8 MB 800.4 kB/s eta 0:00:01
#      ------------------------------------   12.1/12.8 MB 800.4 kB/s eta 0:00:01
#      ------------------------------------   12.1/12.8 MB 792.6 kB/s eta 0:00:01
#      ------------------------------------   12.2/12.8 MB 792.6 kB/s eta 0:00:01
#      ------------------------------------   12.2/12.8 MB 792.6 kB/s eta 0:00:01
#      ------------------------------------   12.3/12.8 MB 809.3 kB/s eta 0:00:01
#      ------------------------------------   12.3/12.8 MB 806.3 kB/s eta 0:00:01
#      ------------------------------------   12.4/12.8 MB 816.4 kB/s eta 0:00:01
#      -------------------------------------  12.5/12.8 MB 821.5 kB/s eta 0:00:01
#      -------------------------------------  12.5/12.8 MB 821.5 kB/s eta 0:00:01
#      -------------------------------------  12.7/12.8 MB 837.2 kB/s eta 0:00:01
#      -------------------------------------  12.8/12.8 MB 842.6 kB/s eta 0:00:01
#      -------------------------------------  12.8/12.8 MB 841.5 kB/s eta 0:00:01
#      -------------------------------------- 12.8/12.8 MB 838.0 kB/s eta 0:00:00
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [notice] A new release of pip is available: 23.1.2 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spacy

nlp = spacy.load("en_core_web_sm", disable=['ner', 'parser'])

# %%
from time import time
import spacy

# Load correct model (make sure it's installed)
nlp = spacy.load("en_core_web_sm", disable=['ner', 'parser'])

t = time()

# Use pipe without n_threads
text = [str(doc) for doc in nlp.pipe(cleaning1, batch_size=5000)]

print('Cleaning time for text: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Cleaning time for text: 1.4 mins

# %%
from time import time

t = time()

summary = ['_START_ ' + str(doc) + ' _END_' 
           for doc in nlp.pipe(cleaning2, batch_size=5000)]

print('Cleaning time for summary: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Cleaning time for summary: 0.33 mins

# %%
text[0]
# Out:
# 'the administration of union territory daman and diu has revoked its order that made it compulsory for women to tie rakhis to their male colleagues on the occasion of rakshabandhan on august 7 the administration was forced to withdraw the decision within 24 hours of issuing the circular after it received flak from employees and was slammed on social media'

# %%
summary[0]
# Out:
# '_START_ daman diu revokes mandatory rakshabandhan in offices order _END_'

# %%
with open('C:/Users/Dell/Downloads/text.txt', "w", encoding='utf-8') as f:
    for item in text:
        f.write(item + '\n')

with open('C:/Users/Dell/Downloads/summary.txt', "w", encoding='utf-8') as f:
    for item in summary:
        f.write(item + '\n')

# %%
pre_data['cleaned_text'] = pd.Series(text)
pre_data['cleaned_summary'] = pd.Series(summary)

# %%
text_count = []
summary_count = []

# %%
pre_data = pre_data.dropna(subset=['cleaned_text', 'cleaned_summary'])

text_count = pre_data['cleaned_text'].apply(lambda x: len(x.split()))
summary_count = pre_data['cleaned_summary'].apply(lambda x: len(x.split()))

# %%
text_count = []
summary_count = []

for sent in pre_data['cleaned_text']:
    text_count.append(len(str(sent).split()))

for sent in pre_data['cleaned_summary']:
    summary_count.append(len(str(sent).split()))

# %%
for sent in pre_data['cleaned_text']:
    text_count.append(len(sent.split()))
for sent in pre_data['cleaned_summary']:
    summary_count.append(len(sent.split()))

# %%
print(graph_df.head())
print(graph_df.shape)
# Out:
# Empty DataFrame
# Columns: [text, summary]
# Index: []
# (0, 2)

# %%
graph_df= pd.DataFrame()
graph_df['text']=text_count
graph_df['summary']=summary_count

# %%
import pandas as pd

text = ["hello world", "machine learning"]
summary = ["greeting", "AI topic"]

graph_df = pd.DataFrame({
    'text': text,
    'summary': summary
})

print(graph_df)
# Out:
#                text   summary
# 0       hello world  greeting
# 1  machine learning  AI topic

# %%
import matplotlib.pyplot as plt

graph_df['text_len'] = graph_df['text'].astype(str).apply(len)
graph_df['summary_len'] = graph_df['summary'].astype(str).apply(len)

graph_df[['text_len', 'summary_len']].hist(bins=5, figsize=(8,4))

plt.tight_layout()
plt.show()

# %%
print(globals().keys())
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '__vsc_ipynb_file__', '_i', '_ii', '_iii', '_i1', 'plt', '_i2', 'pd', '_i3', '_i4', 'text', 'summary', 'graph_df', '_i5', '_i6', '_i7', '_i8', 'count', '_i9'])

# %%
print(graph_df.columns)
# Out:
# Index(['text', 'summary', 'text_len', 'summary_len'], dtype='str')

# %%
count = 0

for i in graph_df['summary']:
    if len(i.split()) <= 15:
        count += 1

print(count)
# Out:
# 2

# %%
#Model to summarize the text between 0-15 words for Summary and 0-100 words for Text

max_text_len=100
max_summary_len=15

# %%
import numpy as np

cleaned_text = np.array(graph_df['text'].astype(str))
cleaned_summary = np.array(graph_df['summary'].astype(str))

# %%
import numpy as np
import pandas as pd

cleaned_text = np.array(graph_df['cleaned_text'].astype(str))
cleaned_summary = np.array(graph_df['cleaned_summary'].astype(str))

short_text = []
short_summary = []

for i in range(len(cleaned_text)):
    if (
        len(cleaned_summary[i].split()) <= max_summary_len and
        len(cleaned_text[i].split()) <= max_text_len
    ):
        short_text.append(cleaned_text[i])
        short_summary.append(cleaned_summary[i])

post_pre_data = pd.DataFrame({
    'text': short_text,
    'summary': short_summary
})

# %%
post_pre_data.head(2)
# Out:
#                text   summary
# 0       hello world  greeting
# 1  machine learning  ai topic

# %%
post_pre_data['summary'] = post_pre_data['summary'].apply(lambda x : 'sostok '+ x + ' eostok')

# %%
post_pre_data.head(2)
# Out:
#                text                 summary
# 0       hello world  sostok greeting eostok
# 1  machine learning  sostok ai topic eostok

# %%
from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(np.array(post_pre_data['text']),np.array(post_pre_data['summary']),test_size=0.1,random_state=0,shuffle=True)

# %%
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences

#prepare a tokenizer for reviews on training data
x_tknizer = Tokenizer() 
x_tknizer.fit_on_texts(list(x_tr))
# Out:
# WARNING:tensorflow:From c:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
thresh=4

count=0
total_count=0
frequency=0
total_frequency=0

for key,value in x_tknizer.word_counts.items():
    total_count=total_count+1
    total_frequency=total_frequency+value
    if(value<thresh):
        count=count+1
        frequency=frequency+value
    
print("% of rare words in vocabulary:",(count/total_count)*100)
print("Total Coverage of rare words:",(frequency/total_frequency)*100)
# Out:
# % of rare words in vocabulary: 100.0
# Total Coverage of rare words: 100.0

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# prepare tokenizer for training data
x_tknizer = Tokenizer(num_words=total_count - count)
x_tknizer.fit_on_texts(list(x_tr))

# convert text to sequences
x_tr_seq  = x_tknizer.texts_to_sequences(x_tr)
x_val_seq = x_tknizer.texts_to_sequences(x_val)

# padding
x_tr  = pad_sequences(x_tr_seq, maxlen=max_text_len, padding='post')
x_val = pad_sequences(x_val_seq, maxlen=max_text_len, padding='post')

# vocabulary size
x_voc = x_tknizer.num_words + 1

print("Size of vocabulary in X =", x_voc)
# Out:
# Size of vocabulary in X = 1

# %%
#prepare a tokenizer for reviews on training data
y_tknizer = Tokenizer()   
y_tknizer.fit_on_texts(list(y_tr))

# %%
thresh=6

count=0
total_count=0
frequency=0
total_frequency=0

for key,value in y_tknizer.word_counts.items():
    total_count=total_count+1
    total_frequency=total_frequency+value
    if(value<thresh):
        count=count+1
        frequency=frequency+value
    
print("% of rare words in vocabulary:",(count/total_count)*100)
print("Total Coverage of rare words:",(frequency/total_frequency)*100)
# Out:
# % of rare words in vocabulary: 100.0
# Total Coverage of rare words: 100.0

# %%
#prepare a tokenizer for reviews on training data
y_tknizer = Tokenizer(num_words=total_count-count) 
y_tknizer.fit_on_texts(list(y_tr))

#convert text sequences into integer sequences (i.e one hot encode the text in Y)
y_tr_seq    =   y_tknizer.texts_to_sequences(y_tr) 
y_val_seq   =   y_tknizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr_seq, maxlen=max_summary_len, padding='post')
y_val   =   pad_sequences(y_val_seq, maxlen=max_summary_len, padding='post')

#size of vocabulary
y_voc  =   y_tknizer.num_words +1
print("Size of vocabulary in Y = {}".format(y_voc))
# Out:
# Size of vocabulary in Y = 1

# %%
ind=[]
for i in range(len(y_tr)):
    count=0
    for j in y_tr[i]:
        if j!=0:
            count=count+1
    if(count==2):
        ind.append(i)

y_tr=np.delete(y_tr,ind, axis=0)
x_tr=np.delete(x_tr,ind, axis=0)

# %%
ind=[]
for i in range(len(y_val)):
    count=0
    for j in y_val[i]:
        if j!=0:
            count=count+1
    if(count==2):
        ind.append(i)

y_val=np.delete(y_val,ind, axis=0)
x_val=np.delete(x_val,ind, axis=0)

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp311-cp311-win_amd64.whl (24.4 MB)
#                                               0.0/24.4 MB ? eta -:--:--
#                                               0.0/24.4 MB ? eta -:--:--
#                                              0.1/24.4 MB 871.5 kB/s eta 0:00:28
#                                              0.1/24.4 MB 991.0 kB/s eta 0:00:25
#                                              0.2/24.4 MB 919.0 kB/s eta 0:00:27
#                                              0.2/24.4 MB 857.5 kB/s eta 0:00:29
#                                              0.2/24.4 MB 962.7 kB/s eta 0:00:26
#                                              0.3/24.4 MB 983.9 kB/s eta 0:00:25
#                                              0.3/24.4 MB 985.2 kB/s eta 0:00:25
#                                              0.4/24.4 MB 997.7 kB/s eta 0:00:25
#                                              0.4/24.4 MB 994.9 kB/s eta 0:00:25
#                                               0.5/24.4 MB 1.0 MB/s eta 0:00:24
#                                               0.6/24.4 MB 1.1 MB/s eta 0:00:23
#                                               0.6/24.4 MB 1.1 MB/s eta 0:00:23
#                                               0.6/24.4 MB 1.1 MB/s eta 0:00:23
#                                               0.6/24.4 MB 1.1 MB/s eta 0:00:23
#                                               0.6/24.4 MB 1.1 MB/s eta 0:00:23
#      -                                       0.6/24.4 MB 816.5 kB/s eta 0:00:30
#      -                                       0.7/24.4 MB 839.1 kB/s eta 0:00:29
#      -                                       0.7/24.4 MB 838.1 kB/s eta 0:00:29
#      -                                       0.8/24.4 MB 862.9 kB/s eta 0:00:28
#      -                                       0.8/24.4 MB 885.2 kB/s eta 0:00:27
#      -                                       0.9/24.4 MB 878.0 kB/s eta 0:00:27
#      -                                       0.9/24.4 MB 878.0 kB/s eta 0:00:27
#      -                                       0.9/24.4 MB 878.0 kB/s eta 0:00:27
#      -                                       0.9/24.4 MB 878.0 kB/s eta 0:00:27
#      -                                       0.9/24.4 MB 767.8 kB/s eta 0:00:31
#      -                                       1.0/24.4 MB 796.6 kB/s eta 0:00:30
#      -                                       1.1/24.4 MB 850.0 kB/s eta 0:00:28
#      -                                       1.1/24.4 MB 852.7 kB/s eta 0:00:28
#      -                                       1.1/24.4 MB 852.7 kB/s eta 0:00:28
#      -                                       1.1/24.4 MB 852.7 kB/s eta 0:00:28
#      -                                       1.1/24.4 MB 852.7 kB/s eta 0:00:28
#      -                                       1.2/24.4 MB 764.6 kB/s eta 0:00:31
4 MB 2.6 MB/s eta 0:00:01
#      ------------------------------------     22.1/24.4 MB 2.6 MB/s eta 0:00:01
#      ------------------------------------     22.1/24.4 MB 2.6 MB/s eta 0:00:01
#      ------------------------------------     22.2/24.4 MB 2.6 MB/s eta 0:00:01
#      ------------------------------------     22.4/24.4 MB 2.6 MB/s eta 0:00:01
#      ------------------------------------     22.5/24.4 MB 2.6 MB/s eta 0:00:01
#      -------------------------------------    22.7/24.4 MB 2.7 MB/s eta 0:00:01
#      -------------------------------------    22.9/24.4 MB 2.7 MB/s eta 0:00:01
#      -------------------------------------    22.9/24.4 MB 2.7 MB/s eta 0:00:01
#      -------------------------------------    22.9/24.4 MB 2.7 MB/s eta 0:00:01
#      -------------------------------------    23.1/24.4 MB 2.7 MB/s eta 0:00:01
#      --------------------------------------   23.2/24.4 MB 2.7 MB/s eta 0:00:01
#      --------------------------------------   23.4/24.4 MB 2.7 MB/s eta 0:00:01
#      --------------------------------------   23.5/24.4 MB 2.7 MB/s eta 0:00:01
#      --------------------------------------   23.6/24.4 MB 2.7 MB/s eta 0:00:01
#      --------------------------------------   23.7/24.4 MB 2.7 MB/s eta 0:00:01
#      ---------------------------------------  23.9/24.4 MB 2.7 MB/s eta 0:00:01
#      ---------------------------------------  24.0/24.4 MB 2.7 MB/s eta 0:00:01
#      ---------------------------------------  24.1/24.4 MB 2.7 MB/s eta 0:00:01
#      ---------------------------------------  24.2/24.4 MB 2.7 MB/s eta 0:00:01
#      ---------------------------------------  24.3/24.4 MB 2.7 MB/s eta 0:00:01
#      ---------------------------------------  24.4/24.4 MB 2.7 MB/s eta 0:00:01
#      ---------------------------------------  24.4/24.4 MB 2.7 MB/s eta 0:00:01
#      ---------------------------------------  24.4/24.4 MB 2.7 MB/s eta 0:00:01
#      ---------------------------------------- 24.4/24.4 MB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.5 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from gensim) (1.17.1)
# Requirement already satisfied: smart_open>=1.8.1 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from gensim) (7.6.0)
# Requirement already satisfied: wrapt in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from smart_open>=1.8.1->gensim) (1.14.2)
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0
# [notice] A new release of pip is available: 23.1.2 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
#                                               0.0/107.7 kB ? eta -:--:--
#      -----------------------------           81.9/107.7 kB 2.3 MB/s eta 0:00:01
#      -------------------------------------- 107.7/107.7 kB 1.2 MB/s eta 0:00:00
# Collecting soupsieve>=1.6.1 (from beautifulsoup4)
#   Downloading soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\dell\appdata\roaming\python\python311\site-packages (from beautifulsoup4) (4.15.0)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.14.3 soupsieve-2.8.3
# [notice] A new release of pip is available: 23.1.2 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# installs (run once if needed)
# !pip install gensim

from keras import backend as K
import gensim
import numpy as np
import pandas as pd
import re
from bs4 import BeautifulSoup

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from nltk.corpus import stopwords
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

import warnings
warnings.filterwarnings("ignore")

pd.set_option("display.max_colwidth", 200)

K.clear_session()

latent_dim = 300
embedding_dim = 200

# ---------------- Encoder ----------------
encoder_inputs = Input(shape=(max_text_len,))

enc_emb = Embedding(x_voc, embedding_dim, trainable=True)(encoder_inputs)

encoder_lstm1 = LSTM(latent_dim, return_sequences=True, return_state=True,
                     dropout=0.4, recurrent_dropout=0.4)

encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

encoder_lstm2 = LSTM(latent_dim, return_sequences=True, return_state=True,
                     dropout=0.4, recurrent_dropout=0.4)

encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

encoder_lstm3 = LSTM(latent_dim, return_sequences=True, return_state=True,
                     dropout=0.4, recurrent_dropout=0.4)

encoder_outputs, state_h, state_c = encoder_lstm3(encoder_output2)

# ---------------- Decoder ----------------
decoder_inputs = Input(shape=(None,))

dec_emb_layer = Embedding(y_voc, embedding_dim, trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True,
                    dropout=0.4, recurrent_dropout=0.2)

decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=[state_h, state_c])

decoder_dense = TimeDistributed(Dense(y_voc, activation='softmax'))
decoder_outputs = decoder_dense(decoder_outputs)

# ---------------- Model ----------------
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 100)]                0         []
#
#  embedding (Embedding)       (None, 100, 200)             200       ['input_1[0][0]']
#
#  lstm (LSTM)                 [(None, 100, 300),           601200    ['embedding[0][0]']
#                               (None, 300),
#                               (None, 300)]
#
#  input_2 (InputLayer)        [(None, None)]               0         []
#
#  lstm_1 (LSTM)               [(None, 100, 300),           721200    ['lstm[0][0]']
#                               (None, 300),
#                               (None, 300)]
#
#  embedding_1 (Embedding)     (None, None, 200)            200       ['input_2[0][0]']
#
#  lstm_2 (LSTM)               [(None, 100, 300),           721200    ['lstm_1[0][0]']
#                               (None, 300),
#                               (None, 300)]
#
#  lstm_3 (LSTM)               [(None, None, 300),          601200    ['embedding_1[0][0]',
#                               (None, 300),                           'lstm_2[0][1]',
#                               (None, 300)]                           'lstm_2[0][2]']
#
#  time_distributed (TimeDist  (None, None, 1)              301       ['lstm_3[0][0]']
#  ributed)
#
# ==================================================================================================
# Total params: 2645501 (10.09 MB)
# Trainable params: 2645501 (10.09 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')
# Out:
# WARNING:tensorflow:From c:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=2)

# %%
model.save_weights('/content/drive/MyDrive/NN_ProjectData/model/fitted_model')

# %%
model = model.load_weights('/content/drive/MyDrive/NN_ProjectData/model/fitted_model')

# %%
print(type(model))
# Out:
# <class 'tensorflow.python.checkpoint.checkpoint.CheckpointLoadStatus'>

# %%
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

# %%
K.clear_session()

model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.compile(
    optimizer='rmsprop',
    loss='sparse_categorical_crossentropy'
)

# %%
reverse_target_word_index=y_tknizer.index_word
reverse_source_word_index=x_tknizer.index_word
target_word_index=y_tknizer.word_index

# %%
from tensorflow.keras import backend as K
K.clear_session()

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)
    
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sostok']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
      
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        
        if(sampled_token!='eostok'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eostok'  or len(decoded_sentence.split()) >= (max_summary_len-1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
def sequence_to_summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['sostok']) and i!=target_word_index['eostok']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def sequence_to_text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
reverse_source_word_index = x_tknizer.index_word

# %%
def sequence_to_text(input_seq):
    newString = ''
    for i in input_seq:
        if i != 0:
            word = reverse_source_word_index.get(i, '')  # SAFE FIX
            newString = newString + word + ' '
    return newString
